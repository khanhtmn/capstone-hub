# %%
"""
This module is used to insert csv file to the database
"""

import pandas as pd
from datetime import datetime
from models import * 
from mapping_enums import class_mapping, college_mapping, concentration_mapping, role_mapping, hsr_mapping

# %%
#### MAIN ####
# Import csv file for students' data
df = pd.read_csv(r'/home/khanh/Documents/capstone-hub/backend/M22_Capstone_descriptions.csv')

#### Process NA values ####
NA_VALUE = "NONE"

# print("BEFORE PROCESSING NAs")
# print(f"Number of NA values: {df.isnull().sum()}")

# df = df.fillna(NA_VALUE)

# print("AFTER PROCESSING NAs")
# print(f"Number of NA values: {df.isnull().sum()}")

enum_cols = {
    "role": role_mapping,
    "primary_major": college_mapping,
    "secondary_major": college_mapping,
    "primary_concentration": concentration_mapping,
    "secondary_concentration": concentration_mapping,
    "minor": college_mapping,
    "minor_concentration": concentration_mapping,
    "hsr_review": hsr_mapping
    }


# Function to create lists of data to inject to Models
"""
Take data and put to dictionary
If column is enum:
    Get equivalent enum data -> Put to tables

"""
def create_list_of_data(data, data_cols, model_cols, default_cols=None, default_vals=None):
    """
    Input:
    dataframe data: Source of data
    list[str] data_cols: Column names from the df data
    list[str] model_cols: Column names from the db model
    list[str] default_cols: Default columns
    list[str] default_vals: Default values for the default columns

    Output:
    list[dict] table_to_insert: Table to insert to database
    """
    n = len(data_cols)
    table_to_insert = []

    for index, row in data.iterrows():
        row_data = dict()
        for i in range(n):
            model_col = model_cols[i]
            data_col = data_cols[i]
            row_value = row[data_col]
            if model_col in enum_cols:
                # Map values from data_col to enum_mapping
                # Then put values from enum_mapping to the row data
                mapper = enum_cols[model_col] # Name of the mapper
                key = row_value # Value of the row aka key of the mapper
                if key in mapper:
                    value = mapper[key] # Value to insert aka value of the mapper
                # elif key == NA_VALUE:
                #     value = ""
                else:
                    value = key
                row_data[model_col] = value
            elif data_col == "timestamp":
                datetime_object = datetime.strptime(row_value, '%m/%d/%Y %H:%M:%S')
                row_data[model_col] = datetime_object
            else:
                # Do normal stuffs
                row_data[model_col] = row_value
        if default_cols:
            for i in range(len(default_cols)):
                row_data[default_cols[i]] = default_vals[i]
        table_to_insert.append(row_data)

    return table_to_insert

# %%
# Logins model
logins_cols = ["id", "public_id", "email"]
logins_data_cols = ["id", "id","email"]
logins_default_cols = ["password"]
logins_default_vals = ["Minerva22"]
logins_to_add = create_list_of_data(\
    data=df,\
    data_cols=logins_data_cols,\
    model_cols=logins_cols,\
    default_cols=logins_default_cols,\
    default_vals=logins_default_vals\
    )

# Users model
users_cols = ["id", "login_id", "name",\
            "primary_major", "secondary_major",\
            "primary_concentration", "secondary_concentration",\
            "special_concentration", "minor", "minor_concentration"]
users_data_cols = ["id", "id", "name",\
                "primary_major", "second_major",\
                "primary_concentration", "second_concentration",\
                "special_concentration", "minor", "minor_concentration"]
users_default_cols = ["role", "class_year"]
users_default_vals = [RoleEnum.student, ClassEnum.M22]
users_to_add = create_list_of_data(\
    data=df,\
    data_cols=users_data_cols,\
    model_cols=users_cols,\
    default_cols=users_default_cols,\
    default_vals=users_default_vals\
    )

print(users_to_add[:1])
print(len(users_to_add))


# Projects model
projects_cols = ["id", "user_id", "title", "abstract",\
                "keywords", "feature", "hsr_review", "skills",\
                "los", "custom_los", "advisor", "skills_offering",\
                "skills_requesting", "location", "last_updated"]
projects_data_cols = ["id", "id", "title", "abstract",\
                "keywords", "features", "hsr_status", "skills",\
                "los", "custom_los", "advisor", "skills_offering",\
                "skills_requesting", "location", "timestamp"]
projects_to_add = create_list_of_data(\
    data=df,\
    data_cols=projects_data_cols,\
    model_cols=projects_cols,\
    )

# %%
# Working model
# Data for User model
Users_to_add = [{
    'id': 1,
    'login_id': 1,
    'firstname': 'Anna',
    'lastname': 'Shallat',
    'role': RoleEnum.student,
    'primary_major': CollegeEnum.AH,
    # 'secondary_major': '',
    'primary_concentration': ConcentrationEnum.AL,
    'secondary_concentration': ConcentrationEnum.PEL,
    # 'special_concentration': '',
    # 'minor': '',
    # 'minor_concentration': '',
}, {
    'id': 2,
    'login_id': 2,
    'firstname': 'Dragon',
    'lastname': 'Cruz-Yen',
    'role': RoleEnum.student,
    'primary_major': CollegeEnum.AH,
    # 'secondary_major': '',
    'primary_concentration': ConcentrationEnum.AL,
    # 'secondary_concentration': '',
    # 'special_concentration': '',
    'minor': CollegeEnum.SS,
    'minor_concentration': ConcentrationEnum.CBB,
}, {
    'id': 3,
    'login_id': 3,
    'firstname': 'Elisha',
    'lastname': 'Somasundram',
    'role': RoleEnum.student,
    'primary_major': CollegeEnum.AH,
    # 'secondary_major': '',
    'primary_concentration': ConcentrationEnum.AL,
    'secondary_concentration': ConcentrationEnum.PEL,
    # 'special_concentration': '',
    'minor': CollegeEnum.SS,
    'minor_concentration': ConcentrationEnum.CBB,
}, {
    'id': 4,
    'login_id': 4,
    'firstname': 'Tessa',
    'lastname': 'Heemskerk',
    'role': RoleEnum.student,
    'primary_major': CollegeEnum.AH,
    # 'secondary_major': '',
    'primary_concentration': ConcentrationEnum.AL,
    # 'secondary_concentration': '',
    # 'special_concentration': '',
    'minor': CollegeEnum.BS,
    # 'minor_concentration': '',
}, {
    'id': 5,
    'login_id': 5,
    'firstname': 'Abigail',
    'lastname': 'Gust',
    'role': RoleEnum.student,
    'primary_major': CollegeEnum.AH,
    # 'secondary_major': '',
    'primary_concentration': ConcentrationEnum.HAN,
    # 'secondary_concentration': '',
    # 'special_concentration': '',
    # 'minor': '',
    # 'minor_concentration': '',
}, {
    'id': 6,
    'login_id': 6,
    'firstname': 'Alya',
    'lastname': 'Luk',
    'role': RoleEnum.student,
    'primary_major': CollegeEnum.AH,
    'secondary_major': CollegeEnum.AH,
    'primary_concentration': ConcentrationEnum.HAP,
    'secondary_concentration': ConcentrationEnum.PEL,
    # 'special_concentration': '',
    'minor': CollegeEnum.CS,
    'minor_concentration': ConcentrationEnum.CSAI,
}]

# %%
print(Users_to_add[0])

# %%
df.head(3)

# %%
"""
This module is used to insert csv file to the database
"""

import pandas as pd
from datetime import datetime
from models import * 
from mapping_enums import class_mapping, college_mapping, concentration_mapping, role_mapping, hsr_mapping

# %%
# Import csv file for students' data
df = pd.read_csv(r'/home/khanh/Documents/capstone-hub/backend/M22_Capstone_descriptions.csv')

# %%
NA_VALUE = "NA"

# print("BEFORE PROCESSING NAs")
# print(f"Number of NA values: {df.isnull().sum()}")

df = df.fillna(NA_VALUE)

# %%
enum_cols = {
    "role": role_mapping,
    "primary_major": college_mapping,
    "secondary_major": college_mapping,
    "primary_concentration": concentration_mapping,
    "secondary_concentration": concentration_mapping,
    "minor": college_mapping,
    "minor_concentration": concentration_mapping,
    "hsr_review": hsr_mapping
    }


# Function to create lists of data to inject to Models
"""
Take data and put to dictionary
If column is enum:
    Get equivalent enum data -> Put to tables

"""
def create_list_of_data(data, data_cols, model_cols, default_cols=None, default_vals=None):
    """
    Input:
    dataframe data: Source of data
    list[str] data_cols: Column names from the df data
    list[str] model_cols: Column names from the db model
    list[str] default_cols: Default columns
    list[str] default_vals: Default values for the default columns

    Output:
    list[dict] table_to_insert: Table to insert to database
    """
    n = len(data_cols)
    table_to_insert = []

    for index, row in data.iterrows():
        row_data = dict()
        for i in range(n):
            model_col = model_cols[i]
            data_col = data_cols[i]
            row_value = row[data_col]
            if model_col in enum_cols:
                # Map values from data_col to enum_mapping
                # Then put values from enum_mapping to the row data
                mapper = enum_cols[model_col] # Name of the mapper
                key = row_value # Value of the row aka key of the mapper
                if key in mapper:
                    value = mapper[key] # Value to insert aka value of the mapper
                # elif key == NA_VALUE:
                #     value = mapper
                else:
                    value = key
                row_data[model_col] = value
            elif data_col == "timestamp":
                datetime_object = datetime.strptime(row_value, '%m/%d/%Y %H:%M:%S')
                row_data[model_col] = datetime_object
            else:
                # Do normal stuffs
                row_data[model_col] = row_value
        if default_cols:
            for i in range(len(default_cols)):
                row_data[default_cols[i]] = default_vals[i]
        table_to_insert.append(row_data)

    return table_to_insert

# %%
# Logins model
logins_cols = ["id", "public_id", "email"]
logins_data_cols = ["id", "id","email"]
logins_default_cols = ["password"]
logins_default_vals = ["Minerva22"]
logins_to_add = create_list_of_data(\
    data=df,\
    data_cols=logins_data_cols,\
    model_cols=logins_cols,\
    default_cols=logins_default_cols,\
    default_vals=logins_default_vals\
    )

# Users model
users_cols = ["id", "login_id", "name",\
            "primary_major", "secondary_major",\
            "primary_concentration", "secondary_concentration",\
            "special_concentration", "minor", "minor_concentration"]
users_data_cols = ["id", "id", "name",\
                "primary_major", "second_major",\
                "primary_concentration", "second_concentration",\
                "special_concentration", "minor", "minor_concentration"]
users_default_cols = ["role", "class_year"]
users_default_vals = [RoleEnum.student, ClassEnum.M22]
users_to_add = create_list_of_data(\
    data=df,\
    data_cols=users_data_cols,\
    model_cols=users_cols,\
    default_cols=users_default_cols,\
    default_vals=users_default_vals\
    )

print(users_to_add[:1])
print(len(users_to_add))


# Projects model
projects_cols = ["id", "user_id", "title", "abstract",\
                "keywords", "feature", "hsr_review", "skills",\
                "los", "custom_los", "advisor", "skills_offering",\
                "skills_requesting", "location", "last_updated"]
projects_data_cols = ["id", "id", "title", "abstract",\
                "keywords", "features", "hsr_status", "skills",\
                "los", "custom_los", "advisor", "skills_offering",\
                "skills_requesting", "location", "timestamp"]
projects_to_add = create_list_of_data(\
    data=df,\
    data_cols=projects_data_cols,\
    model_cols=projects_cols,\
    )

# print(projects_to_add[:3])
# print(len(projects_to_add))


def insert_data(dict_to_add, table):
    """To insert data"""
    # import sqlite3

    # db = sqlite3.connect("database.db")
    # cur = db.cursor()


    # Create application context to add data to the database
    from app import create_app
    my_app = create_app()
    my_app.app_context().push()

    # List of keys with (list_of_data, model) to iterate
    # keys = [(logins_to_add, Login), (users_to_add, User), (projects_to_add, Project)]
    # Insert data
    # for dict_to_add, table in keys:
    for dict_row in dict_to_add:
        try:
            stmt = table(**dict_row)
            db.session.add(stmt)
            db.session.commit()
        except Exception as e:
            db.session.rollback()
            print(e)
            continue
        finally:
            db.session.close()
# Out:
# [{'id': 1, 'login_id': 1, 'name': 'Vick Boyu Liu', 'primary_major': <CollegeEnum.AH: 'Arts & Humanities'>, 'secondary_major': <CollegeEnum.BS: 'Business'>, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>, 'secondary_concentration': <ConcentrationEnum.NBV: 'New Business Ventures'>, 'special_concentration': nan, 'minor': nan, 'minor_concentration': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum.M22: 'Class of 2022'>}]
# 143

# %%
insert_data(logins_to_add, Login)
# Out:
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(1) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 1, 'public_id': 1, 'email': 'vick_liu@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(2) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 2, 'public_id': 2, 'email': 'gabrielle.vonseggern@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(3) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 3, 'public_id': 3, 'email': 'arshallat@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(4) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 4, 'public_id': 4, 'email': 'dragoncy@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(5) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 5, 'public_id': 5, 'email': 'elisha@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(6) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 6, 'public_id': 6, 'email': 'theemskerk@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(7) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 7, 'public_id': 7, 'email': 'abigail.gust@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(8) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 8, 'public_id': 8, 'email': 'alya@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(9) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 9, 'public_id': 9, 'email': 'angelina.rubis@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(10) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 10, 'public_id': 10, 'email': 'cristina.acevedo@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(11) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 11, 'public_id': 11, 'email': 'xiaohan.wu@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(12) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 12, 'public_id': 12, 'email': 'sscarfone@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(13) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 13, 'public_id': 13, 'email': 'apilla@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(14) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 14, 'public_id': 14, 'email': 'camilalmn@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(15) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 15, 'public_id': 15, 'email': 'hle@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(16) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 16, 'public_id': 16, 'email': 'phoeberose@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(17) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 17, 'public_id': 17, 'email': 'rahelbruszt@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(18) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 18, 'public_id': 18, 'email': 'nutsa.metreveli@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(19) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 19, 'public_id': 19, 'email': 'phchaule@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(20) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 20, 'public_id': 20, 'email': 'loan.nguyen@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(21) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 21, 'public_id': 21, 'email': 'sarahpoisner@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(22) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 22, 'public_id': 22, 'email': 'soominkim25@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(23) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 23, 'public_id': 23, 'email': 'xinyi@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(24) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 24, 'public_id': 24, 'email': 'anungoo@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(25) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 25, 'public_id': 25, 'email': 'mosinski@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(26) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 26, 'public_id': 26, 'email': 'guzel@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(27) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 27, 'public_id': 27, 'email': 'julia.ip@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(28) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 28, 'public_id': 28, 'email': 'oliverfeuerhahn@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(29) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 29, 'public_id': 29, 'email': 'sandra.kuzmenko@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(30) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 30, 'public_id': 30, 'email': 'stella.odiwuor@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(31) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 31, 'public_id': 31, 'email': 'viktoriia@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(32) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 32, 'public_id': 32, 'email': 'mark.ndoli@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(33) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 33, 'public_id': 33, 'email': 'karina@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(34) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 34, 'public_id': 34, 'email': 'abdelkader@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(35) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 35, 'public_id': 35, 'email': 'charlottejuan@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(36) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 36, 'public_id': 36, 'email': 'adel@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(37) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 37, 'public_id': 37, 'email': 'sadidhasan@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(38) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 38, 'public_id': 38, 'email': 'johannes@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(39) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 39, 'public_id': 39, 'email': 'alexandra.butmalai@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(40) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 40, 'public_id': 40, 'email': 'junyoung@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(41) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 41, 'public_id': 41, 'email': 'shpend@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(42) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 42, 'public_id': 42, 'email': 'go@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(43) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 43, 'public_id': 43, 'email': 'heyou@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(44) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 44, 'public_id': 44, 'email': 'abdurrehmanasif@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(45) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 45, 'public_id': 45, 'email': 'hatem@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(46) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 46, 'public_id': 46, 'email': 'kasisi@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(47) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 47, 'public_id': 47, 'email': 'alexander.kamande@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(48) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 48, 'public_id': 48, 'email': 'anzhelika.korolova@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(49) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 49, 'public_id': 49, 'email': 'lauren.childs@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(50) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 50, 'public_id': 50, 'email': 'fatin_noor.m22@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(51) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 51, 'public_id': 51, 'email': 'msdlamini@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(52) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 52, 'public_id': 52, 'email': 'barbaramachado@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(53) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 53, 'public_id': 53, 'email': 'rhythmehta@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(54) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 54, 'public_id': 54, 'email': 'a.bricken@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(55) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 55, 'public_id': 55, 'email': 'anosha@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(56) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 56, 'public_id': 56, 'email': 'arnav.hazra@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(57) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 57, 'public_id': 57, 'email': 'dima@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(58) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 58, 'public_id': 58, 'email': 'frederik.hardervig@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(59) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 59, 'public_id': 59, 'email': 'magali.debruyn@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(60) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 60, 'public_id': 60, 'email': 'verina.armanyous@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(61) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 61, 'public_id': 61, 'email': 'ara.mkhoyan@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(62) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 62, 'public_id': 62, 'email': 'shukai@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(63) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 63, 'public_id': 63, 'email': 'akmarzhan@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(64) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 64, 'public_id': 64, 'email': 'emanuel@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(65) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 65, 'public_id': 65, 'email': 'trang18@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(66) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 66, 'public_id': 66, 'email': 'minh.nguyen@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(67) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 67, 'public_id': 67, 'email': 'haitham.hyder@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(68) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 68, 'public_id': 68, 'email': 'batsal@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(69) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 69, 'public_id': 69, 'email': 'singh@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(70) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 70, 'public_id': 70, 'email': 'guilhermehohenfeld@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(71) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 71, 'public_id': 71, 'email': 'jacknyange@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(72) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 72, 'public_id': 72, 'email': 'kareem@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(73) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 73, 'public_id': 73, 'email': 'khanh@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(74) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 74, 'public_id': 74, 'email': 'lucas.mudo@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(75) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 75, 'public_id': 75, 'email': 'luccabertoncini@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(76) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 76, 'public_id': 76, 'email': 'mikulas.plesak@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(77) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 77, 'public_id': 77, 'email': 'pierrealkubeh@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(78) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 78, 'public_id': 78, 'email': 'valdrinj@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(79) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 79, 'public_id': 79, 'email': 'rafa.bastos@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(80) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 80, 'public_id': 80, 'email': 'anglilian@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(81) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 81, 'public_id': 81, 'email': 'amenti@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(82) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 82, 'public_id': 82, 'email': 'claudiagold@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(83) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 83, 'public_id': 83, 'email': 'idrissbennis@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(84) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 84, 'public_id': 84, 'email': 'juraj.vasek@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(85) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 85, 'public_id': 85, 'email': 'lanceaquino@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(86) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 86, 'public_id': 86, 'email': 'viktoriia.honcharuk@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(87) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 87, 'public_id': 87, 'email': 'kuba.warmuz@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(88) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 88, 'public_id': 88, 'email': 'tiagoflora@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(89) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 89, 'public_id': 89, 'email': 'yhhuang@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(90) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 90, 'public_id': 90, 'email': 'cameronwatts@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(91) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 91, 'public_id': 91, 'email': 'carlos.rafael.ga@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(92) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 92, 'public_id': 92, 'email': 'albionkrasniqi22@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(93) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 93, 'public_id': 93, 'email': 'asantacruz@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(94) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 94, 'public_id': 94, 'email': 'ayoola@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(95) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 95, 'public_id': 95, 'email': 'cyrus@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(96) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 96, 'public_id': 96, 'email': 'daniel.hernandez@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(97) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 97, 'public_id': 97, 'email': 'jinkim@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(98) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 98, 'public_id': 98, 'email': 'resende@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(99) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 99, 'public_id': 99, 'email': 'koredeakande@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(100) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 100, 'public_id': 100, 'email': 'pedrojudice@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(101) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 101, 'public_id': 101, 'email': 'svitlana@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(102) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 102, 'public_id': 102, 'email': 'hanna@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(103) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 103, 'public_id': 103, 'email': 'ibuk.lola@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(104) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 104, 'public_id': 104, 'email': 'j.alvarez@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(105) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 105, 'public_id': 105, 'email': 'adeena@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(106) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 106, 'public_id': 106, 'email': 'grace.sommers@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(107) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 107, 'public_id': 107, 'email': 'xiaoning@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(108) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 108, 'public_id': 108, 'email': 'yael.mc@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(109) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 109, 'public_id': 109, 'email': 'zixuan@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(110) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 110, 'public_id': 110, 'email': 'yaremko.nazar@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(111) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 111, 'public_id': 111, 'email': 'vanyasofia@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(112) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 112, 'public_id': 112, 'email': 'woluchukwu@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(113) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 113, 'public_id': 113, 'email': 'ali@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(114) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 114, 'public_id': 114, 'email': 'millie@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(115) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 115, 'public_id': 115, 'email': 'enjui.chang@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(116) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 116, 'public_id': 116, 'email': 'simon.andren@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(117) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 117, 'public_id': 117, 'email': 'megan.perpich@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(118) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 118, 'public_id': 118, 'email': 'isabelevitorio@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(119) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 119, 'public_id': 119, 'email': 'jatin.kansal@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(120) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 120, 'public_id': 120, 'email': 'mahmud.nobe@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(121) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 121, 'public_id': 121, 'email': 'xavier@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(122) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 122, 'public_id': 122, 'email': 'aspenpflughoeft@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(123) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 123, 'public_id': 123, 'email': 'ellastreng@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(124) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 124, 'public_id': 124, 'email': 'leandrapedretti@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(125) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 125, 'public_id': 125, 'email': 'patrycja@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(126) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 126, 'public_id': 126, 'email': 'emilyemily@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(127) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 127, 'public_id': 127, 'email': 'stephane@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(128) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 128, 'public_id': 128, 'email': 'alma.gashi@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(129) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 129, 'public_id': 129, 'email': 'nataliavelasco@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(130) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 130, 'public_id': 130, 'email': 'yunxin.gu@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(131) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 131, 'public_id': 131, 'email': 'anna.nevmerzhytska@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(132) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 132, 'public_id': 132, 'email': 'leon@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(133) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 133, 'public_id': 133, 'email': 'lina.dellalibera@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(134) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 134, 'public_id': 134, 'email': 'guillermo@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(135) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 135, 'public_id': 135, 'email': 'lxia@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(136) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 136, 'public_id': 136, 'email': 'mewes@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(137) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 137, 'public_id': 137, 'email': 'zachzhu@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(138) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 138, 'public_id': 138, 'email': 'asma.lam@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(139) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 139, 'public_id': 139, 'email': 'christopherw@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(140) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 140, 'public_id': 140, 'email': 'samad@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(141) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 141, 'public_id': 141, 'email': 'abraham13@minerva.kgi.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(142) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 142, 'public_id': 142, 'email': 'anastasiya@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "logins_pkey"
# DETAIL:  Key (id)=(143) already exists.
#
# [SQL: INSERT INTO logins (id, public_id, email, password) VALUES (%(id)s, %(public_id)s, %(email)s, %(password)s)]
# [parameters: {'id': 143, 'public_id': 143, 'email': 'iryna.bilohorka@uni.minerva.edu', 'password': 'Minerva22'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
insert_data(users_to_add, User)
# Out:
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.NBV: 'New Business Ventures'>, 'id': 1, 'minor': nan, 'role': <RoleEnum.st ... (164 characters truncated) ... _major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'id': 2, 'minor': nan, 'role': <Ro ... (188 characters truncated) ... _major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>, 'id': 3, 'minor': nan, 'role': <R ... (148 characters truncated) ... _major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'secondary_concentration': nan, 'id': 4, 'minor': <CollegeEnum.SS: ... (182 characters truncated) ... _major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'secondary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Et ... (240 characters truncated) ... _major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 6, 'minor': <CollegeEnum.BS: 'Business'>, 'role': <RoleEnum.student: 'Student'>, ' ... (121 characters truncated) ... _major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 7, 'minor': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum.M ... (94 characters truncated) ... major': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.HAN: 'Humanities Analyses'>}]]
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (id)=(8) already exists.
#
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: {'id': 8, 'login_id': 8, 'name': 'Alya Luk', 'role': 'student', 'class_year': 'M22', 'primary_major': 'AH', 'secondary_major': 'AH', 'primary_concentration': 'HAP', 'secondary_concentration': 'PEL', 'special_concentration': nan, 'minor': 'CS', 'minor_concentration': 'CSAI'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'id': 9, 'minor': nan, 'role': <Ro ... (186 characters truncated) ... r': <CollegeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.HAP: 'Humanities Applications'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>, 'id': 10, 'minor': nan, 'role': <RoleEnum.stud ... (203 characters truncated) ... ntration': 'I am also concentrating in Philosophy, Ethics, and the Law', 'primary_concentration': <ConcentrationEnum.HAP: 'Humanities Applications'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 11, 'minor': nan, 'role': <Role ... (204 characters truncated) ... legeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ES: "Earth's Systems">, 'id': 12, 'minor': nan, 'role': <RoleEnum.student: ... (182 characters truncated) ... legeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.PGS: 'Politics, Government, and Society'>, 'id': 13, 'minor': nan, 'role': ... (197 characters truncated) ... legeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.PGS: 'Politics, Government, and Society'>, 'id': 14, 'minor': nan, 'role': ... (213 characters truncated) ... legeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': '**Custom / special concentration**', 'id': 15, 'minor': nan, 'role': <RoleEnum.student: 'Stu ... (210 characters truncated) ... _concentration': 'International Political and Economic Systems', 'primary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.HFC: 'Historical Forces'>, 'id': 16, 'minor': nan, 'role': <RoleEnum.stude ... (149 characters truncated) ... legeEnum.AH: 'Arts & Humanities'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.AL: 'Arts and Literature'>, 'id': 17, 'minor': nan, 'role': <RoleEnum.stud ... (159 characters truncated) ... t', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (id)=(18) already exists.
#
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: {'id': 18, 'login_id': 18, 'name': 'Nutsa Metreveli', 'role': 'student', 'class_year': 'M22', 'primary_major': 'BS', 'secondary_major': 'BS', 'primary_concentration': 'BM', 'secondary_concentration': 'SF', 'special_concentration': nan, 'minor': 'SS', 'minor_concentration': 'ECS'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.APS: 'Applied Problem Solving'>, 'id': 19, 'minor': nan, 'role': <RoleEnum ... (164 characters truncated) ... e', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 20, 'minor': nan, 'role': <Role ... (172 characters truncated) ... n', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 21, 'minor': nan, 'role': <Role ... (174 characters truncated) ... r', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 22, 'minor': nan, 'role': <Role ... (171 characters truncated) ... m', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 23, 'minor': nan, 'role': <Role ... (169 characters truncated) ... i', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ES: "Earth's Systems">, 'id': 24, 'minor': nan, 'role': <RoleEnum.student: ... (162 characters truncated) ... n', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'id': 25, 'minor': nan, 'role': <R ... (172 characters truncated) ... i', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'id': 26, 'minor': nan, 'role': <R ... (174 characters truncated) ... a', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.BM: 'Brand Management'>, 'id': 27, 'minor': nan, 'role': <RoleEnum.student ... (153 characters truncated) ... ry_major': <CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.DS: 'Designing Societies'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DS: 'Designing Societies'>, 'id': 28, 'minor': nan, 'role': <RoleEnum.stud ... (161 characters truncated) ... n', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'secondary_concentration': <ConcentrationEnum.MOC: 'Managing Opera ... (240 characters truncated) ... o', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'secondary_concentration': nan, 'id': 30, 'minor': <CollegeEnum.SS ... (171 characters truncated) ... r', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.BM: 'Brand Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 31, 'minor': nan, 'role': <Role ... (186 characters truncated) ... primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.EM: 'Enterprise Management'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>, 'id': 32, 'minor': nan, 'role': <RoleEnum.studen ... (162 characters truncated) ... or': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.MOC: 'Managing Operational Complexity'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': '**Custom / special concentration**', 'id': 33, 'minor': nan, 'role': <RoleEnum.student: 'Stu ... (199 characters truncated) ... >, 'special_concentration': 'Global Governance and Development', 'primary_concentration': <ConcentrationEnum.MOC: 'Managing Operational Complexity'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'secondary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>, 'id ... (221 characters truncated) ... or': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.MOC: 'Managing Operational Complexity'>}]]
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (id)=(35) already exists.
#
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: {'id': 35, 'login_id': 35, 'name': 'Hsin-Hsieh (Charlotte) Juan', 'role': 'student', 'class_year': 'M22', 'primary_major': 'BS', 'secondary_major': 'BS', 'primary_concentration': 'NBV', 'secondary_concentration': 'BM', 'special_concentration': nan, 'minor': 'SS', 'minor_concentration': 'CBB'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>, 'secondary_concentration': nan, 'id': 36, 'minor': <CollegeEnum.SS ... (176 characters truncated) ... rimary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.NBV: 'New Business Ventures'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 37, 'minor': nan, 'role': <Role ... (175 characters truncated) ... an', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SG: 'Scalable Growth'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'id': 38, 'minor': nan, 'role': <RoleEnum.s ... (165 characters truncated) ... an', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SG: 'Scalable Growth'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': '**Custom / special concentration**', 'id': 39, 'minor': nan, 'role': <RoleEnum.student: 'Stu ... (191 characters truncated) ... um.BS: 'Business'>, 'special_concentration': 'Global Governance and Development', 'primary_concentration': <ConcentrationEnum.SG: 'Scalable Growth'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.SG: 'Scalable Growth'>, 'secondary_concentration': nan, 'id': 40, 'minor': <CollegeEnum.BS: 'Business'>, ' ... (174 characters truncated) ... egeEnum.CS: 'Computational Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 41, 'minor': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum. ... (84 characters truncated) ... ri', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SG: 'Scalable Growth'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.APS: 'Applied Problem Solving'>, 'id': 42, 'minor': nan, 'role': <RoleEnum ... (176 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.APS: 'Applied Problem Solving'>, 'id': 43, 'minor': nan, 'role': <RoleEnum ... (167 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'id': 44, 'minor': nan, 'role': <Role ... (187 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'id': 45, 'minor': nan, 'role': <RoleEnum.s ... (160 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'id': 46, 'minor': nan, 'role': <RoleEnum.s ... (164 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.EM: 'Enterprise Management'>, 'id': 47, 'minor': nan, 'role': <RoleEnum.st ... (143 characters truncated) ... or': <CollegeEnum.BS: 'Business'>, 'special_concentration': 'Brand Management', 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 48, 'minor': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum. ... (90 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.BM: 'Brand Management'>, 'id': 49, 'minor': nan, 'role': <RoleEnum.student ... (124 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'secondary_concentration': <ConcentrationEnum.EM: 'Enterprise Management'>, ... (212 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.EM: 'Enterprise Management'>, 'id': 51, 'minor': nan, 'role': <RoleEnum.st ... (131 characters truncated) ... ', 'primary_major': <CollegeEnum.BS: 'Business'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.BM: 'Brand Management'>, 'id': 52, 'minor': nan, 'role': <RoleEnum.student ... (193 characters truncated) ... egeEnum.CS: 'Computational Sciences'>, 'special_concentration': 'Data Science and AI', 'primary_concentration': '**Custom / special concentration**'}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.BM: 'Brand Management'>, 'id': 53, 'minor': nan, 'role': <RoleEnum.student ... (155 characters truncated) ... mary_major': <CollegeEnum.CS: 'Computational Sciences'>, 'special_concentration': nan, 'primary_concentration': '**Custom / special concentration**'}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# ...
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.HFC: 'Historical Forces'>, 'id': 126, 'minor': nan, 'role': <RoleEnum.stud ... (183 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.BM: 'Brand Management'>, 'id': 127, 'minor': nan, 'role': <RoleEnum.studen ... (174 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: concentrationenum. Possible values: APS, AL, BM, ..., CSC
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 128, 'minor': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum ... (190 characters truncated) ... oncentration': 'Artificial Intelligence and Simulation Modeling', 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'id': 129, 'minor': nan, 'role': <RoleEnum. ... (187 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>, 'id': 130, 'minor': nan, 'role': <RoleEnum. ... (181 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.DS: 'Designing Societies'>, 'id': 131, 'minor': nan, 'role': <RoleEnum.stu ... (155 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 132, 'minor': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum ... (106 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>, 'secondary_concentration': <ConcentrationEnum.PGS: 'Politics, Gov ... (258 characters truncated) ... CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.CBB: 'Cognition, Brain, and Behavior'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.SG: 'Scalable Growth'>, 'id': 134, 'minor': nan, 'role': <RoleEnum.student ... (172 characters truncated) ... ry_major': <CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.DS: 'Designing Societies'>}]]
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (id)=(135) already exists.
#
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: {'id': 135, 'login_id': 135, 'name': 'Linda (L) Xia', 'role': 'student', 'class_year': 'M22', 'primary_major': 'SS', 'secondary_major': 'CS', 'primary_concentration': 'DS', 'secondary_concentration': 'CSAI', 'special_concentration': nan, 'minor': 'AH', 'minor_concentration': 'PEL'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.ES: "Earth's Systems">, 'secondary_concentration': nan, 'id': 136, 'minor': <CollegeEnum.NS: 'Natural Scie ... (163 characters truncated) ... ry_major': <CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.DS: 'Designing Societies'>}]]
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "users_pkey"
# DETAIL:  Key (id)=(137) already exists.
#
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: {'id': 137, 'login_id': 137, 'name': 'Zichen Zhu (Zach)', 'role': 'student', 'class_year': 'M22', 'primary_major': 'SS', 'secondary_major': 'CS', 'primary_concentration': 'ECS', 'secondary_concentration': 'CSAI', 'special_concentration': nan, 'minor': 'CS', 'minor_concentration': 'CSAI'}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.DSS: 'Data Science and Statistics'>, 'secondary_concentration': nan, 'id': 138, 'minor': <CollegeEnum.CS:  ... (191 characters truncated) ... major': <CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': <ConcentrationEnum.PEL: 'Philosophy, Ethics, and the Law'>, 'secondary_concentration': nan, 'id': 139, 'minor': <CollegeEnum. ... (190 characters truncated) ... major': <CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': nan, 'id': 140, 'minor': nan, 'role': <RoleEnum.student: 'Student'>, 'class_year': <ClassEnum ... (106 characters truncated) ... major': <CollegeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.ECS: 'Economics and Society'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.HAP: 'Humanities Applications'>, 'id': 141, 'minor': nan, 'role': <RoleEnu ... (195 characters truncated) ... legeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PGS: 'Politics, Government, and Society'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.SF: 'Strategic Finance'>, 'id': 142, 'minor': nan, 'role': <RoleEnum.stude ... (179 characters truncated) ... legeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PGS: 'Politics, Government, and Society'>}]]
# (builtins.LookupError) 'nan' is not among the defined enum values. Enum name: collegeenum. Possible values: CS, BS, NS, ..., SS
# [SQL: INSERT INTO users (id, login_id, name, role, class_year, primary_major, secondary_major, primary_concentration, secondary_concentration, special_concentration, minor, minor_concentration) VALUES (%(id)s, %(login_id)s, %(name)s, %(role)s, %(class_year)s, %(primary_major)s, %(secondary_major)s, %(primary_concentration)s, %(secondary_concentration)s, %(special_concentration)s, %(minor)s, %(minor_concentration)s)]
# [parameters: [{'minor_concentration': nan, 'secondary_concentration': <ConcentrationEnum.ES: "Earth's Systems">, 'id': 143, 'minor': nan, 'role': <RoleEnum.student ... (184 characters truncated) ... legeEnum.SS: 'Social Sciences'>, 'special_concentration': nan, 'primary_concentration': <ConcentrationEnum.PGS: 'Politics, Government, and Society'>}]]

# %%
insert_data(projects_to_add, Project)

# %%
df.head(3)
# Out:
#            timestamp  id                                 email  \
# 0  9/11/2021 8:05:28   1              vick_liu@uni.minerva.edu
# 1  9/18/2021 9:05:17   2  gabrielle.vonseggern@uni.minerva.edu
# 2  9/16/2021 9:59:12   3             arshallat@uni.minerva.edu
#
#                     name      primary_major primary_concentration  \
# 0          Vick Boyu Liu  Arts & Humanities   Arts and Literature
# 1  Gabrielle Von Seggern  Arts & Humanities   Arts and Literature
# 2           Anna Shallat  Arts & Humanities   Arts and Literature
#
#       second_major             second_concentration special_concentration  \
# 0         Business            New Business Ventures                   NaN
# 1  Social Sciences   Cognition, Brain, and Behavior                   NaN
# 2              NaN  Philosophy, Ethics, and the Law                   NaN
#
#   minor  ...                                           keywords  \
# 0   NaN  ...  Theater, Historical Trauma, Best Practices, So...
# 1   NaN  ...  Mythology, ancient cultures, creative, illustr...
# 2   NaN  ...                  Zines, Ethics, LGBTQ+, subculture
#
#                                             features  \
# 0  Creative (e.g., writing, art), Secondary resea...
# 1  Creative (e.g., writing, art), Secondary resea...
# 2  Creative (e.g., writing, art), Secondary resea...
#
#                                           hsr_status  \
# 0  N/A (project does NOT involve interacting with...
# 1  N/A (project does NOT involve interacting with...
# 2  N/A (project does NOT involve interacting with...
#
#                                               skills  \
# 0  Music theory, basic song writing and theatre p...
# 1  Film theory (especially visual theories and us...
# 2  - illustration technique\n- creative writing\n...
#
#                                                  los  \
# 0  #ah166-produceArt\n#b144-Implementation\n#ah11...
# 1  #ah110primarysources, #ah110historicalperspect...
# 2  #ah144ethicaltheory,\n#ah146rupturesanddisloca...
#
#                  custom_los   advisor  \
# 0  #playwriting\n#PitchDeck    Kamler
# 1                       NaN  Fiorelli
# 2                       NaN   Bogucki
#
#                                      skills_offering  \
# 0                                   Comics,  Musical
# 1                                                NaN
# 2  Dance, storytelling, humor, illustration, text...
#
#                                    skills_requesting  \
# 0                     Art producing and music theory
# 1                                                NaN
# 2  education, sketching/painting, animation/video...
#
#                     location
# 0  London (BST then GMT/UTC)
# 1             Berlin (GMT+2)
# 2               Peoria (CST)
#
# [3 rows x 23 columns]
